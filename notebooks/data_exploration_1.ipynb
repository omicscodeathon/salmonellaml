# %%
#import required libraries
import pandas as pd
# https://3months.tistory.com/234 _SNP

# %%
# load data
df=pd.read_table("../data/kenya.tsv")
df.head()
# Out:
#        #Organism group          Strain  \
# 0  Salmonella enterica  ILBSalm5516455
# 1  Salmonella enterica     CFSAN031424
# 2  Salmonella enterica     CFSAN031428
# 3  Salmonella enterica     CFSAN031429
# 4  Salmonella enterica     CFSAN031422
#
#                                  Isolate identifiers      Serovar  \
# 0  03_0448-sc-2013-06-10T14:57:22Z-1611313,"ERS25...  Enteritidis
# 1            CFSAN031424,"ICOPHAI16572","SRS1034405"          NaN
# 2            CFSAN031428,"ICOPHAI16576","SRS1034403"          NaN
# 3            CFSAN031429,"ICOPHAI16577","SRS1034401"          NaN
# 4            CFSAN031422,"ICOPHAI16569","SRS1034409"          NaN
#
#           Isolate           Create date Location Isolation source  \
# 0  PDT000031325.2  2014-05-29T14:53:32Z    Kenya            blood
# 1  PDT000105258.2  2016-02-05T15:24:43Z    Kenya      feces swine
# 2  PDT000105259.2  2016-02-05T15:24:43Z    Kenya      feces swine
# ...

# %%
# extract Biosamples and save to txt file
# Assuming you have a DataFrame named 'df' and a column named 'column_name'
column_data = df['BioSample']

# Save the column data to a text file
column_data.to_csv('../accessions/kenya_biosamples.txt', index=False, header=False)
